# %% [markdown]
# <a href="https://colab.research.google.com/github/rmogi/HousePrice/blob/master/HosePrices_stacking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-87570110-87e5-4d4d-80e9-76f56539888d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87570110-87e5-4d4d-80e9-76f56539888d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv
# ...

# %%
#必要なライブラリをインポートする
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
from scipy import stats
from scipy.stats import norm, skew
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

#学習データの変数を確認
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#トレーニングデータの確認
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#テストデータの確認
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
#データサイズの確認
print("shape train: %s, test: %s" % (train.shape, test.shape))
# Out:
# shape train: (1460, 81), test: (1459, 80)

# %%
#IDのカラムは不必要なので別の変数に格納
train_ID = train['Id']
test_ID = test['Id']

train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#それぞれのデータの最ぞを確認
print("shape train: %s, test: %s" % (train.shape, test.shape))
# Out:
# shape train: (1460, 80), test: (1459, 79)

# %%
#地上の広さと物件価格に散布図を作成
fig, ax = plt.subplots(figsize=(20, 8))
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=15)
plt.xlabel('GrLivArea', fontsize=15)
plt.show()

# %%
#外れ値を除外する
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

#地上の広さと物件価格に散布図を作成
fig, ax = plt.subplots(figsize=(20, 8))
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=15)
plt.xlabel('GrLivArea', fontsize=15)
plt.show()

# %%
#築年数と物件価格の散布図を作成
data = pd.concat([train["YearBuilt"],train["SalePrice"]],axis=1)

fig, ax = plt.subplots(figsize=(20, 8))
plt.xticks(rotation='90')
sns.boxplot(x="YearBuilt",y="SalePrice",data=data)

# %%
#外れ値を除外する
train = train.drop(train[(train['YearBuilt']<2000) & (train['SalePrice']>600000)].index)

#グラフを描画する
data = pd.concat([train["YearBuilt"],train["SalePrice"]],axis=1)

fig, ax = plt.subplots(figsize=(20, 8))
plt.xticks(rotation='90')
sns.boxplot(x="YearBuilt",y="SalePrice",data=data)

# %%
#家の材質・完成度と物件価格の散布図を作成
fig, ax = plt.subplots(figsize=(20, 8))
plt.scatter(train["OverallQual"],train["SalePrice"])
plt.xlabel("OverallQual", fontsize=15)
plt.ylabel("SalePrice", fontsize=15)
plt.show()

# %%
#外れ値を除外する
train = train.drop(train[(train['OverallQual']<5) & (train['SalePrice']>200000)].index)
train = train.drop(train[(train['OverallQual']<10) & (train['SalePrice']>500000)].index)

#グラフを描画する
fig, ax = plt.subplots(figsize=(20, 8))
plt.scatter(train["OverallQual"],train["SalePrice"])
plt.xlabel("OverallQual", fontsize=15)
plt.ylabel("SalePrice", fontsize=15)
plt.show()

# %%
#目的変数である家の価格のヒストグラムを表示する
plt.figure(figsize=(20, 10))
sns.distplot(train['SalePrice'])

# %%
#目的変数の対数log(x+1)をとる
train["SalePrice"] = np.log1p(train["SalePrice"])

#分布を可視化
plt.figure(figsize=(20, 10))
sns.distplot(train['SalePrice'])

# %%
#特徴量エンジニアリング
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("shape all_data : {}".format(all_data.shape))
# Out:
# shape all_data : (2908, 79)

# %%
#データの欠損値を確認する
all_data_na = all_data.isnull().sum()[all_data.isnull().sum()>0].sort_values(ascending=False)
all_data_na
# Out:
# PoolQC          2900
# MiscFeature     2803
# Alley           2710
# Fence           2338
# FireplaceQu     1420
# LotFrontage      485
# GarageFinish     159
# GarageYrBlt      159
# GarageQual       159
# GarageCond       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# BsmtFullBath       2
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# Exterior2nd        1
# Exterior1st        1
# SaleType           1
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# Electrical         1
# KitchenQual        1
# GarageCars         1
# GarageArea         1
# TotalBsmtSF        1
# dtype: int64

# %%
#欠損値の数をグラフ化
plt.figure(figsize=(20,10), facecolor="w")
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)

# %%
# 欠損値があるカラムをリスト化
na_col_list = all_data.isnull().sum()[all_data.isnull().sum()>0].index.tolist()

#欠損があるカラムのデータ型を確認
all_data[na_col_list].dtypes.sort_values()
# Out:
# TotalBsmtSF     float64
# BsmtUnfSF       float64
# BsmtFinSF2      float64
# BsmtFinSF1      float64
# GarageYrBlt     float64
# BsmtFullBath    float64
# GarageCars      float64
# BsmtHalfBath    float64
# GarageArea      float64
# LotFrontage     float64
# MasVnrArea      float64
# GarageQual       object
# GarageCond       object
# GarageType       object
# PoolQC           object
# FireplaceQu      object
# Fence            object
# Functional       object
# KitchenQual      object
# GarageFinish     object
# MSZoning         object
# MiscFeature      object
# BsmtFinType2     object
# BsmtFinType1     object
# BsmtExposure     object
# BsmtCond         object
# BsmtQual         object
# MasVnrType       object
# Exterior2nd      object
# Exterior1st      object
# Utilities        object
# Alley            object
# Electrical       object
# SaleType         object
# dtype: object

# %%
# データ型に応じて欠損値を補完する
# floatの場合は0
# objectの場合は'NA'
na_float_cols = all_data[na_col_list].dtypes[all_data[na_col_list].dtypes=='float64'].index.tolist() #float64
na_obj_cols = all_data[na_col_list].dtypes[all_data[na_col_list].dtypes=='object'].index.tolist() #object
# float64型で欠損している場合は0を代入
for na_float_col in na_float_cols:
    all_data.loc[all_data[na_float_col].isnull(),na_float_col] = 0.0
# object型で欠損している場合は'NA'を代入
for na_obj_col in na_obj_cols:
    all_data.loc[all_data[na_obj_col].isnull(),na_obj_col] = 'NA'

# %%
#欠損値が全て置換できているか確認
all_data.isnull().sum()[all_data.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
#カテゴリ変数に変換する
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)

all_data['OverallCond'] = all_data['OverallCond'].astype(str)

all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %%
#カラムをラベルエンコーディングで数値化
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
 
#列を処理し、LabelEncoderをカテゴリカル機能に適用する
for c in cols:
  lbl = LabelEncoder() 
  lbl.fit(list(all_data[c].values)) 
  all_data[c] = lbl.transform(list(all_data[c].values))
 
print('shape all_data: {}'.format(all_data.shape))
# Out:
# shape all_data: (2908, 79)

# %%
#物件の広さを合計した変数を作成
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %%
#特徴量の歪み補正
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness
# Out:
# Skew in numerical features:
#                  Skew
# MiscVal        21.906
# PoolArea       18.679
# LotArea        13.507
# LowQualFinSF   12.066
# 3SsnPorch      11.354
# LandSlope       5.009
# KitchenAbvGr    4.293
# BsmtFinSF2      4.137
# EnclosedPorch   3.995
# ScreenPorch     3.965
# BsmtHalfBath    3.937
# MasVnrArea      2.563
# OpenPorchSF     2.536
# WoodDeckSF      1.854
# 1stFlrSF        1.260
# BsmtFinSF1      0.963
# GrLivArea       0.958
# TotalSF         0.921
# BsmtUnfSF       0.917
# 2ndFlrSF        0.836
# TotRmsAbvGrd    0.731
# Fireplaces      0.730
# HalfBath        0.703
# TotalBsmtSF     0.661
# BsmtFullBath    0.626
# OverallCond     0.566
# HeatingQC       0.480
# FireplaceQu     0.335
# BedroomAbvGr    0.333
# GarageArea      0.210
# OverallQual     0.176
# FullBath        0.149
# MSSubClass      0.142
# YrSold          0.132
# BsmtFinType1    0.080
# LotFrontage    -0.134
# GarageCars     -0.219
# YearRemodAdd   -0.446
# BsmtQual       -0.490
# ...

# %%
#大きく歪んだ特徴量は、ボックスコックス変換を使って補正する
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))
 
from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)
# Out:
# There are 59 skewed numerical features to Box Cox transform

# %%
#カテゴリ変数をダミー変数に変換
all_data = pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (2908, 229)

# %%
#学習データとテストデータに再分割
train = all_data.iloc[:train.shape[0],:].reset_index(drop=True)
test = all_data.iloc[train.shape[0]:,:].reset_index(drop=True)

# %%
#モデリング
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# K-Fold**sクロス検証イテレーター**
#
# トレーニング/テストインデックスを提供して、データをトレーニングテストセットに分割します。データセットをkの連続する折りたたみに分割します(シャッフルなし)。
#
# 次に、各フォールドは検証セットを1回使用し、残りのk-1フォールドはトレーニングセットを形成します。

# %%
#クロスバリデーションの定義
#複数のモデルで活用するため、関数化しておく
n_folds = 5
 
def rmsle_cv(model):
  kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
  #交差検証によってスコアを評価する
  rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
  return(rmse)

# %%
#LASSO回帰
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

# %%
#Elastic Net Regression
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

# %%
#Kernel Ridge Regression
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

# %%
#Gradient Boosting
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %%
#XGBoost
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %%
#LightGBM
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
#ベースモデルのスコア
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
 
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
 
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
 
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
 
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
 
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1104 (0.0072)
#
# ElasticNet score: 0.1104 (0.0073)
#
# Kernel Ridge score: 0.1147 (0.0067)
#
# Gradient Boosting score: 0.1168 (0.0071)
#
# Xgboost score: 0.1151 (0.0051)
#
# LGBM score: 0.1144 (0.0065)

# %% [markdown]
# **BaseEsimator：**
#
# scikit-learnのすべての推定量の基本クラス
#
# **RegressorMixin：**
#
# scikit-learnのすべての回帰推定量のMixinクラス
#
# **TransformerMixin：**
#
# scikit-learnのすべてのトランスフォーマーのMixinクラス

# %%
#stackingモデルの作成
#各学習機の予測結果の平均をとるためのクラスの作成
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    #データを収めるためにもとのモデルのクローンを定義する
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        #複製された基本モデルのトレーニング
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #次に、クローンモデルの予測を行い、それらを平均化する
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
#LASSO回帰, Elastic Net Regression, Kernel Ridge Regression, XGBoostの平均化する
averaged_models = AveragingModels(models = (lasso, ENet, KRR, GBoost))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1078 (0.0071)

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    #元のモデルのクローンにデータを再度当てはめます
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        #複製された基本モデルをトレーニングしてから、範囲外予測を作成します
        #クローンされたメタモデルをトレーニングするために必要なもの
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        #今度は、範囲外予測を新機能として使用して、複製されたメタモデルをトレーニングします。
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #テストデータですべてのベースモデルの予測を行い、平均化された予測を次のように使用します。
    #メタモデルによって行われる最終的な予測のためのメタ機能
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %%
#（同じ数のモデルを使用して）2つのアプローチを比較できるようにするために、Enet KRRとGboostを平均化し、次にLassoをメタモデルとして追加します。
stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR),meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1077 (0.0069)

# %%
#メタ学習を追加することで、より良いスコアが再び得られる

#StackedRegressor、XGBoost、LightGBMの組み合わせ

#以前に定義したStackedRegressorにXGBoostとLightGBMを追加します。

#まず、rmsle評価関数を定義します

def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %% [markdown]
# 最終トレーニングと予測

# %%
#StackedRegressor
stacked_averaged_models.fit(train.values, y_train)
stacked_train_pred = stacked_averaged_models.predict(train.values)
stacked_pred = np.expm1(stacked_averaged_models.predict(test.values))
print(rmsle(y_train, stacked_train_pred))
# Out:
# 0.07471687086444719

# %%
#XGBoost
model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
xgb_pred = np.expm1(model_xgb.predict(test))
print(rmsle(y_train, xgb_train_pred))
# Out:
# 0.07888930093348978

# %%
#LightGBM
model_lgb.fit(train, y_train)
lgb_train_pred = model_lgb.predict(train)
lgb_pred = np.expm1(model_lgb.predict(test.values))
print(rmsle(y_train, lgb_train_pred))
# Out:
# 0.07191351450048113

# %%
#平均化時のトレーニングデータ全体のRMSE

print('RMSLE score on train data:')
print(rmsle(y_train,stacked_train_pred*0.70 +
               xgb_train_pred*0.15 + lgb_train_pred*0.15 ))
# Out:
# RMSLE score on train data:
# 0.07303390403788577

# %%
#アンサンブル予測
ensemble = stacked_pred*0.70 + xgb_pred*0.15 + lgb_pred*0.15

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('HousePrices_Stacking.csv',index=False)
